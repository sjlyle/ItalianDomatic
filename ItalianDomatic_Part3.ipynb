# %%
#*********************************************
#Output from previous code segment, saved in a 
#  list, then checked for isomorphisms.
#   
#                               1/14/2021 Lyle
#
#  Update (6/9/21) Create output levels
#*********************************************

#set to 0 for less print statements
output_level = 1;


#From Graph Gr1
Output  = ['QEYbtZSZrtTlt[tkult]i]ujYlO']
#From Graph Gr2
Output.append('QEYblZWZrtTlu[tkuxdZm]ujUl_');

#From Gr3 --- no possible graphs.
#From Gr4 --- no possible graphs.
#From Gr5 --- no possible graphs.
#From Gr6
Output.append('QEYdZXtmb^UmucuTuuusuZyjTlO');
#From Gr7

#Note, r included to change to raw strings (avoid problems with backslash escape characters)
Output.append(r'QBjB\jWjrtYktZjtNVBtZt\inZ?');
Output.append(r'QBjB\jWmZmXsrjm\MzBmZrlixz?');
Output.append(r'QBjB\jWmZmXsrjm\MzBmZrlixz?');
Output.append(r'QBjB\jWtZtTwjrt\NVBtZjtjTz?');
Output.append(r'QBjB\jWrjmVKmZrlMzBmZm\jMz?');
Output.append(r'QBjB\jWjujNStZ]lTzBtZjtjTz?');
Output.append(r'QBjB\jWm]\Mwrj\tVNBmZm\jMz?');
Output.append(r'QBjB\jWt\]NSjr]lYnBtZt\inZ?');
Output.append(r'QBjB\jWrlrMwmZ\tXvBmZrlixz?');
Output.append(r'QBjB\jWmZmXs\rrlVNE\Zm\hvZ?');
Output.append(r'QBjB\jWjrtYk]jt\TzEjZjthyz?');
Output.append(r'QBjB\jWtZtTw]jjtYnD]Zt\hyz?');
Output.append(r'QBjB\jWrjmVK\rm\XvDrZrlhvZ?');
Output.append(r'QBjB\jWm]\Mw\rm\XvE\Z\tixz?');
Output.append(r'QBjB\jWjujNS]jjtYnEjZ]linZ?');
Output.append(r'QBjB\jWt\]NS]jt\TzD]Z]ljTz?');
Output.append(r'QBjB\jWrlrMw\rrlVNDrZ\tjMz?');
Output.append(r'QBjB\jW\trXsmZrlMzE\Z\tixz?');
Output.append(r'QBjB\jW]l]Ykjrt\NVEjZ]linZ?');
Output.append(r'QBjB\jW\u\VKrjm\MzDrZ\tjMz?');
Output.append(r'QBjB\jW]mjTwtZjtNVD]Z]ljTz?');
Output.append(r'QBjB\jW\u\VKmZ\tXvE\Zm\hvZ?');
Output.append(r'QBjB\jW]mjTwjr]lYnEjZjthyz?');
Output.append(r'QBjB\jW\trXsrj\tVNDrZrlhvZ?');
Output.append(r'QBjB\jW]l]YktZ]lTzD]Zt\hyz?');


L2 = [];
uniquecount = 0;

#Check for isomorphisms
for i in range(len(Output)):
    j = 1;
    unique = true;
    while(j<uniquecount):

        G1 = Graph(Output[i], sparse=True);
        G2 = Graph(L2[j], sparse=True);

        if(G1.is_isomorphic(G2)):
            unique = false;
            if (output_level > 0):
                print i ,' is isomorphic to ', j
            
        j = j+1;
    if (unique):
        L2.append(Output[i]);
        uniquecount = uniquecount + 1;


print('Non-isomorphic Candidates:')    
for i in range(len(L2)):
    print'Graph', i ,":", L2[i]
# Out:
# 4  is isomorphic to  3
# 5  is isomorphic to  3
# 6  is isomorphic to  3
# 7  is isomorphic to  3
# 8  is isomorphic to  3
# 9  is isomorphic to  3
# 10  is isomorphic to  3
# 11  is isomorphic to  3
# 12  is isomorphic to  3
# 13  is isomorphic to  3
# 14  is isomorphic to  3
# 15  is isomorphic to  3
# 16  is isomorphic to  3
# 17  is isomorphic to  3
# 18  is isomorphic to  3
# 19  is isomorphic to  3
# 20  is isomorphic to  3
# 21  is isomorphic to  3
# 22  is isomorphic to  3
# 23  is isomorphic to  3
# 24  is isomorphic to  3
# 25  is isomorphic to  3
# 26  is isomorphic to  3
# 27  is isomorphic to  3
# Non-isomorphic Candidates:
# Graph 0 : QEYbtZSZrtTlt[tkult]i]ujYlO
# Graph 1 : QEYblZWZrtTlu[tkuxdZm]ujUl_
# Graph 2 : QEYdZXtmb^UmucuTuuusuZyjTlO
# Graph 3 : QBjB\jWjrtYktZjtNVBtZt\inZ?
